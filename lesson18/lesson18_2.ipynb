# %%
import random
import numpy as np
import pandas as pd

with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)

with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df
# Out:
#       國文  英文  數學   地理   歷史
# 黃志福   88  76  98   77   96
# 郭坤花   99  89  94   96   69
# 陳慧君   73  62  72   60   64
# 謝哲維   94  89  99   93   53
# 游治旺   90  68  73   60   74
# 郭淑真   85  62  75   63   95
# 張慧君   77  65  98   89   68
# 余丞苓   61  69  70   77   67
# 童建霖   97  94  79   94   70
# 楊火帆   82  92  63   99  100
# 吳晴洋   72  65  69   65   66
# 劉萬季   67  92  63   93   65
# 周怡啟   85  76  77   51   72
# 郭致恬   66  68  58   66   65
# 劉嘉泰   67  65  93   79   93
# 黃嘉琪   89  65  78   70   97
# 蔡明平   94  65  59   78   90
# 周琬婷   57  88  78  100   84
# 劉耿琦   93  86  57   54   66
# 姜琬婷   94  61  53   52   83
# 沈心利   84  75  99   77   63
# 方筠紹   90  57  77   67   90
# 童建霖   99  50  93   53   61
# 陳美惠   91  63  99   61   50
# 杜明延   80  74  64   50   88
# 游倫城   78  89  57   71   78
# 陳信念   50  94  97   90   96
# 游一鈺   75  91  92   64   82
# 吳振瑋   73  92  72   57   68
# 陳冠霞   90  69  59   64   75
# 張婕妤   65  76  94   60   59
# 高信宏   99  89  55   67   87
# 楊綺芬  100  88  64   54   81
# 楊韋廷   78  89  77   89   61
# 尚偉倫   91  56  64   58   65
# 賴昌韻   68  95  60  100   73
# 林益妏   57  93  77   62   80
# 黃婷婷   99  89  96   82   64
# 陳志偉   82  96  86   79   64
# 陳嘉淑   57  78  65   62   74
# 李蓉瑞   72  61  72   91   87
# 陳凱翔   69  98  76   96   92
# 陳怡容   61  54  89   70   74
# 盧文啟   96  73  64   66   55
# 王泓泰   61  74  54   57   99
# 吳柏誠   55  87  59   82   77
# 龔姵君   58  73  50   56   95
# 吳明妮   91  57  52   73   94
# 張莉雯   93  53  75   51   59
# 洪奎夫   74  85  54   90   98

# %%
from pandas import Series,DataFrame
def fun3(s:Series):
    sum = s.sum()
    mean = s.mean()
    count = s[s<60].count()
    values = s[s<60].index.values
    return Series([sum,mean,count,values],index=['總分','平均','不及格數','不及格科目'])

student_df.apply(fun3,axis=1)
# Out:
#       總分    平均  不及格數         不及格科目
# 黃志福  435  87.0     0            []
# 郭坤花  447  89.4     0            []
# 陳慧君  331  66.2     0            []
# 謝哲維  428  85.6     1          [歷史]
# 游治旺  365  73.0     0            []
# 郭淑真  380  76.0     0            []
# 張慧君  397  79.4     0            []
# 余丞苓  344  68.8     0            []
# 童建霖  434  86.8     0            []
# 楊火帆  436  87.2     0            []
# 吳晴洋  337  67.4     0            []
# 劉萬季  380  76.0     0            []
# 周怡啟  361  72.2     1          [地理]
# 郭致恬  323  64.6     1          [數學]
# 劉嘉泰  397  79.4     0            []
# 黃嘉琪  399  79.8     0            []
# 蔡明平  386  77.2     1          [數學]
# 周琬婷  407  81.4     1          [國文]
# 劉耿琦  356  71.2     2      [數學, 地理]
# 姜琬婷  343  68.6     2      [數學, 地理]
# 沈心利  398  79.6     0            []
# 方筠紹  381  76.2     1          [英文]
# 童建霖  356  71.2     2      [英文, 地理]
# 陳美惠  364  72.8     1          [歷史]
# 杜明延  356  71.2     1          [地理]
# 游倫城  373  74.6     1          [數學]
# 陳信念  427  85.4     1          [國文]
# 游一鈺  404  80.8     0            []
# 吳振瑋  362  72.4     1          [地理]
# 陳冠霞  357  71.4     1          [數學]
# 張婕妤  354  70.8     1          [歷史]
# 高信宏  397  79.4     1          [數學]
# 楊綺芬  387  77.4     1          [地理]
# 楊韋廷  394  78.8     0            []
# 尚偉倫  334  66.8     2      [英文, 地理]
# 賴昌韻  396  79.2     0            []
# 林益妏  369  73.8     1          [國文]
# 黃婷婷  430  86.0     0            []
# 陳志偉  407  81.4     0            []
# 陳嘉淑  336  67.2     1          [國文]
# 李蓉瑞  383  76.6     0            []
# 陳凱翔  431  86.2     0            []
# 陳怡容  348  69.6     1          [英文]
# 盧文啟  354  70.8     1          [歷史]
# 王泓泰  345  69.0     2      [數學, 地理]
# 吳柏誠  360  72.0     2      [國文, 數學]
# 龔姵君  332  66.4     3  [國文, 數學, 地理]
# 吳明妮  367  73.4     2      [英文, 數學]
# 張莉雯  331  66.2     3  [英文, 地理, 歷史]
# 洪奎夫  401  80.2     1          [數學]
