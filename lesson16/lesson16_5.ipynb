# %%
import random
with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)
names
# Out:
# ['林義皓',
#  '盧冠發',
#  '林柏洋',
#  '林義皓',
#  '高智超',
#  '郭舜昇',
#  '林志喜',
#  '李慈啟',
#  '林玉佩',
#  '游詩亞',
#  '游倫城',
#  '溫重意',
#  '蔡孟泉',
#  '翁鈺婷',
#  '張家秀',
#  '童建霖',
#  '蔡偉成',
#  '吳淑惠',
#  '王坤安',
#  '臧怡君',
#  '陳逸華',
#  '陳倩潔',
#  '盧冠發',
#  '朱士弘',
#  '蕭淑華',
#  '郭坤花',
#  '張韋成',
#  '張彥博',
#  '黃善迪',
#  '林怡偉',
#  '劉依婷',
#  '元延辛',
#  '吳麗卿',
#  '林向鈺',
#  '蔡明平',
#  '臧怡君',
#  '溫法堯',
#  '傅佳琳',
#  '陳筱涵',
#  '許芳如',
#  '胡姿婷',
#  '林義皓',
#  '高信宏',
#  '沈心利',
#  '林志成',
#  '方筠紹',
#  '紀亮亮',
#  '張凡成',
#  '余丞苓',
#  '郭淑真']

# %%
import numpy as np
import pandas as pd
with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df
# Out:
#       國文   英文   數學  地理   歷史
# 林義皓   64   64   79  79   83
# 盧冠發   62   87   80  53   92
# 林柏洋   86   53   61  71   80
# 林義皓   57   98  100  58   87
# 高智超   69   90   84  77   99
# 郭舜昇   97   92   83  67   98
# 林志喜   85   92   77  62   73
# 李慈啟   62   89   58  60   76
# 林玉佩  100  100   62  84  100
# 游詩亞   73   88   53  93   97
# 游倫城   58   67   68  98   67
# 溫重意   62   71   69  81   85
# 蔡孟泉   69   72   62  87   68
# 翁鈺婷   76   93   61  71   98
# 張家秀   66   74   97  75   97
# 童建霖   59   79   50  90   62
# 蔡偉成   61   63   93  89   79
# 吳淑惠   84   94   67  66   96
# 王坤安   92   70  100  62   64
# 臧怡君   68   56   57  85   64
# 陳逸華   98   85   64  86   69
# 陳倩潔  100   72   81  51   66
# 盧冠發   71   89   92  90   86
# 朱士弘   53   54   83  61   70
# 蕭淑華   68   64   65  51   74
# 郭坤花   91   74   71  88   66
# 張韋成   73   80   66  72   94
# 張彥博   70   61   52  51   90
# 黃善迪   73   95   77  80   66
# 林怡偉   94   51   56  69   57
# 劉依婷   97   66   72  95   98
# 元延辛   67   77   62  63   99
# 吳麗卿   86  100   92  99   80
# 林向鈺   72   95   69  91   58
# 蔡明平   64   62   62  50   54
# 臧怡君   72   85   72  56   76
# 溫法堯   55   80   67  80   98
# 傅佳琳   95   57   64  53   88
# 陳筱涵   93   65   58  71   85
# 許芳如   56   64   69  84   57
# 胡姿婷   56   83   81  69   96
# 林義皓   98   78   86  70   69
# 高信宏   60   99   97  83   82
# 沈心利   81   76   63  94   87
# 林志成   67   75   95  97   59
# 方筠紹   54   82   95  78   55
# 紀亮亮   53   95   66  63   51
# 張凡成   86   93   76  90   82
# 余丞苓   86   78   51  96   96
# 郭淑真   61   64   84  83   69

# %%
#選取dataframe的一個欄位
display(student_df['國文'])
display(student_df['英文'])
# Out:
# 林義皓     64
# 盧冠發     62
# 林柏洋     86
# 林義皓     57
# 高智超     69
# 郭舜昇     97
# 林志喜     85
# 李慈啟     62
# 林玉佩    100
# 游詩亞     73
# 游倫城     58
# 溫重意     62
# 蔡孟泉     69
# 翁鈺婷     76
# 張家秀     66
# 童建霖     59
# 蔡偉成     61
# 吳淑惠     84
# 王坤安     92
# 臧怡君     68
# 陳逸華     98
# 陳倩潔    100
# 盧冠發     71
# 朱士弘     53
# 蕭淑華     68
# 郭坤花     91
# 張韋成     73
# 張彥博     70
# 黃善迪     73
# 林怡偉     94
# 劉依婷     97
# 元延辛     67
# 吳麗卿     86
# 林向鈺     72
# 蔡明平     64
# 臧怡君     72
# 溫法堯     55
# 傅佳琳     95
# 陳筱涵     93
# 許芳如     56
# 胡姿婷     56
# 林義皓     98
# 高信宏     60
# 沈心利     81
# 林志成     67
# 方筠紹     54
# 紀亮亮     53
# 張凡成     86
# 余丞苓     86
# 郭淑真     61
# Name: 國文, dtype: int32
# 林義皓     64
# 盧冠發     87
# 林柏洋     53
# 林義皓     98
# 高智超     90
# 郭舜昇     92
# 林志喜     92
# 李慈啟     89
# 林玉佩    100
# 游詩亞     88
# 游倫城     67
# 溫重意     71
# 蔡孟泉     72
# 翁鈺婷     93
# 張家秀     74
# 童建霖     79
# 蔡偉成     63
# 吳淑惠     94
# 王坤安     70
# 臧怡君     56
# 陳逸華     85
# 陳倩潔     72
# 盧冠發     89
# 朱士弘     54
# 蕭淑華     64
# 郭坤花     74
# 張韋成     80
# 張彥博     61
# 黃善迪     95
# 林怡偉     51
# 劉依婷     66
# 元延辛     77
# 吳麗卿    100
# 林向鈺     95
# 蔡明平     62
# 臧怡君     85
# 溫法堯     80
# 傅佳琳     57
# 陳筱涵     65
# 許芳如     64
# 胡姿婷     83
# 林義皓     78
# 高信宏     99
# 沈心利     76
# 林志成     75
# 方筠紹     82
# 紀亮亮     95
# 張凡成     93
# 余丞苓     78
# 郭淑真     64
# Name: 英文, dtype: int32

# %%
#選取dataframe的多個欄位
student_df[['國文','英文']]
# Out:
#       國文   英文
# 林義皓   64   64
# 盧冠發   62   87
# 林柏洋   86   53
# 林義皓   57   98
# 高智超   69   90
# 郭舜昇   97   92
# 林志喜   85   92
# 李慈啟   62   89
# 林玉佩  100  100
# 游詩亞   73   88
# 游倫城   58   67
# 溫重意   62   71
# 蔡孟泉   69   72
# 翁鈺婷   76   93
# 張家秀   66   74
# 童建霖   59   79
# 蔡偉成   61   63
# 吳淑惠   84   94
# 王坤安   92   70
# 臧怡君   68   56
# 陳逸華   98   85
# 陳倩潔  100   72
# 盧冠發   71   89
# 朱士弘   53   54
# 蕭淑華   68   64
# 郭坤花   91   74
# 張韋成   73   80
# 張彥博   70   61
# 黃善迪   73   95
# 林怡偉   94   51
# 劉依婷   97   66
# 元延辛   67   77
# 吳麗卿   86  100
# 林向鈺   72   95
# 蔡明平   64   62
# 臧怡君   72   85
# 溫法堯   55   80
# 傅佳琳   95   57
# 陳筱涵   93   65
# 許芳如   56   64
# 胡姿婷   56   83
# 林義皓   98   78
# 高信宏   60   99
# 沈心利   81   76
# 林志成   67   75
# 方筠紹   54   82
# 紀亮亮   53   95
# 張凡成   86   93
# 余丞苓   86   78
# 郭淑真   61   64

# %%
sum_series = student_df['國文'] + \
student_df['英文'] + \
student_df['數學'] + \
student_df['地理'] + \
student_df['歷史'] 
mean_series = sum_series / 5
mean_series
# Out:
# 林義皓    73.8
# 盧冠發    74.8
# 林柏洋    70.2
# 林義皓    80.0
# 高智超    83.8
# 郭舜昇    87.4
# 林志喜    77.8
# 李慈啟    69.0
# 林玉佩    89.2
# 游詩亞    80.8
# 游倫城    71.6
# 溫重意    73.6
# 蔡孟泉    71.6
# 翁鈺婷    79.8
# 張家秀    81.8
# 童建霖    68.0
# 蔡偉成    77.0
# 吳淑惠    81.4
# 王坤安    77.6
# 臧怡君    66.0
# 陳逸華    80.4
# 陳倩潔    74.0
# 盧冠發    85.6
# 朱士弘    64.2
# 蕭淑華    64.4
# 郭坤花    78.0
# 張韋成    77.0
# 張彥博    64.8
# 黃善迪    78.2
# 林怡偉    65.4
# 劉依婷    85.6
# 元延辛    73.6
# 吳麗卿    91.4
# 林向鈺    77.0
# 蔡明平    58.4
# 臧怡君    72.2
# 溫法堯    76.0
# 傅佳琳    71.4
# 陳筱涵    74.4
# 許芳如    66.0
# 胡姿婷    77.0
# 林義皓    80.2
# 高信宏    84.2
# 沈心利    80.2
# 林志成    78.6
# 方筠紹    72.8
# 紀亮亮    65.6
# 張凡成    85.4
# 余丞苓    81.4
# 郭淑真    72.2
# dtype: float64

# %%
student_df['總分'] = sum_series
student_df['平均'] = mean_series
student_df
# Out:
#       國文   英文   數學  地理   歷史   總分    平均
# 林義皓   64   64   79  79   83  369  73.8
# 盧冠發   62   87   80  53   92  374  74.8
# 林柏洋   86   53   61  71   80  351  70.2
# 林義皓   57   98  100  58   87  400  80.0
# 高智超   69   90   84  77   99  419  83.8
# 郭舜昇   97   92   83  67   98  437  87.4
# 林志喜   85   92   77  62   73  389  77.8
# 李慈啟   62   89   58  60   76  345  69.0
# 林玉佩  100  100   62  84  100  446  89.2
# 游詩亞   73   88   53  93   97  404  80.8
# 游倫城   58   67   68  98   67  358  71.6
# 溫重意   62   71   69  81   85  368  73.6
# 蔡孟泉   69   72   62  87   68  358  71.6
# 翁鈺婷   76   93   61  71   98  399  79.8
# 張家秀   66   74   97  75   97  409  81.8
# 童建霖   59   79   50  90   62  340  68.0
# 蔡偉成   61   63   93  89   79  385  77.0
# 吳淑惠   84   94   67  66   96  407  81.4
# 王坤安   92   70  100  62   64  388  77.6
# 臧怡君   68   56   57  85   64  330  66.0
# 陳逸華   98   85   64  86   69  402  80.4
# 陳倩潔  100   72   81  51   66  370  74.0
# 盧冠發   71   89   92  90   86  428  85.6
# 朱士弘   53   54   83  61   70  321  64.2
# 蕭淑華   68   64   65  51   74  322  64.4
# 郭坤花   91   74   71  88   66  390  78.0
# 張韋成   73   80   66  72   94  385  77.0
# 張彥博   70   61   52  51   90  324  64.8
# 黃善迪   73   95   77  80   66  391  78.2
# 林怡偉   94   51   56  69   57  327  65.4
# 劉依婷   97   66   72  95   98  428  85.6
# 元延辛   67   77   62  63   99  368  73.6
# 吳麗卿   86  100   92  99   80  457  91.4
# 林向鈺   72   95   69  91   58  385  77.0
# 蔡明平   64   62   62  50   54  292  58.4
# 臧怡君   72   85   72  56   76  361  72.2
# 溫法堯   55   80   67  80   98  380  76.0
# 傅佳琳   95   57   64  53   88  357  71.4
# 陳筱涵   93   65   58  71   85  372  74.4
# 許芳如   56   64   69  84   57  330  66.0
# 胡姿婷   56   83   81  69   96  385  77.0
# 林義皓   98   78   86  70   69  401  80.2
# 高信宏   60   99   97  83   82  421  84.2
# 沈心利   81   76   63  94   87  401  80.2
# 林志成   67   75   95  97   59  393  78.6
# 方筠紹   54   82   95  78   55  364  72.8
# 紀亮亮   53   95   66  63   51  328  65.6
# 張凡成   86   93   76  90   82  427  85.4
# 余丞苓   86   78   51  96   96  407  81.4
# 郭淑真   61   64   84  83   69  361  72.2
