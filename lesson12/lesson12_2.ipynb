# %%
from os.path import abspath,dirname,join

file_path:str = join(dirname(abspath(__name__)),'data','peoples.csv')
file_path
# Out:
# '/workspaces/lesson12/data/peoples.csv'

# %%
from csv import DictReader
from pprint import pprint

with open(file_path,encoding='utf-8',newline='') as file:
    reader = DictReader(file)
    pprint(list(reader))
# Out:
# [{'BMI': '18.13', '姓名': '王柏聖', '狀態': '體重過輕', '身高': '171', '體重': '53'},
#  {'BMI': '29.52', '姓名': '馬彥文', '狀態': '輕度肥胖', '身高': '154', '體重': '70'},
#  {'BMI': '20.83', '姓名': '張俊傑', '狀態': '體重正常', '身高': '161', '體重': '54'},
#  {'BMI': '32.45', '姓名': '李政白', '狀態': '中度肥胖', '身高': '158', '體重': '81'},
#  {'BMI': '31.57', '姓名': '聶心怡', '狀態': '中度肥胖', '身高': '166', '體重': '87'},
#  {'BMI': '24.9', '姓名': '李慈啟', '狀態': '體重過重', '身高': '188', '體重': '88'},
#  {'BMI': '21.33', '姓名': '葉祖雄', '狀態': '體重正常', '身高': '185', '體重': '73'},
#  {'BMI': '22.05', '姓名': '翁羽威', '狀態': '體重正常', '身高': '173', '體重': '66'},
#  {'BMI': '24.98', '姓名': '王明昇', '狀態': '體重過重', '身高': '165', '體重': '68'},
#  {'BMI': '26.03', '姓名': '黃翔杰', '狀態': '體重過重', '身高': '172', '體重': '77'},
#  {'BMI': '17.65', '姓名': '王士銘', '狀態': '體重過輕', '身高': '170', '體重': '51'},
#  {'BMI': '19.59', '姓名': '游一鈺', '狀態': '體重正常', '身高': '175', '體重': '60'},
#  {'BMI': '16.13', '姓名': '游一鈺', '狀態': '體重過輕', '身高': '188', '體重': '57'},
#  {'BMI': '22.05', '姓名': '朱士弘', '狀態': '體重正常', '身高': '173', '體重': '66'},
#  {'BMI': '18.34', '姓名': '馬彥文', '狀態': '體重過輕', '身高': '170', '體重': '53'},
#  {'BMI': '15.4', '姓名': '姜琬婷', '狀態': '體重過輕', '身高': '182', '體重': '51'},
#  {'BMI': '26.22', '姓名': '吳麗卿', '狀態': '體重過重', '身高': '150', '體重': '59'},
#  {'BMI': '27.61', '姓名': '孫火清', '狀態': '輕度肥胖', '身高': '167', '體重': '77'},
#  {'BMI': '24.24', '姓名': '吳淑惠', '狀態': '體重過重', '身高': '165', '體重': '66'},
#  {'BMI': '25.34', '姓名': '王柏聖', '狀態': '體重過重', '身高': '181', '體重': '83'},
#  {'BMI': '26.64', '姓名': '林冠蕙', '狀態': '體重過重', '身高': '170', '體重': '77'},
#  {'BMI': '22.72', '姓名': '林世城', '狀態': '體重正常', '身高': '173', '體重': '68'},
#  {'BMI': '24.49', '姓名': '林怡偉', '狀態': '體重過重', '身高': '175', '體重': '75'},
#  {'BMI': '16.79', '姓名': '楊綺芬', '狀態': '體重過輕', '身高': '181', '體重': '55'},
#  {'BMI': '26.89', '姓名': '林瑞喬', '狀態': '體重過重', '身高': '167', '體重': '75'},
#  {'BMI': '26.29', '姓名': '杜明延', '狀態': '體重過重', '身高': '184', '體重': '89'},
#  {'BMI': '25.08', '姓名': '吳俐芷', '狀態': '體重過重', '身高': '183', '體重': '84'},
#  {'BMI': '17.17', '姓名': '李政成', '狀態': '體重過輕', '身高': '190', '體重': '62'},
#  {'BMI': '27.05', '姓名': '黎惠雯', '狀態': '輕度肥胖', '身高': '162', '體重': '71'},
#  {'BMI': '33.76', '姓名': '陳怡珊', '狀態': '中度肥胖', '身高': '152', '體重': '78'},
#  {'BMI': '27.61', '姓名': '洪阿惠', '狀態': '輕度肥胖', '身高': '167', '體重': '77'},
#  {'BMI': '24.24', '姓名': '賴苑禾', '狀態': '體重過重', '身高': '152', '體重': '56'},
#  {'BMI': '24.96', '姓名': '楊火帆', '狀態': '體重過重', '身高': '171', '體重': '73'},
#  {'BMI': '26.58', '姓名': '楊易政', '狀態': '體重過重', '身高': '184', '體重': '90'},
#  {'BMI': '19.61', '姓名': '邱亭君', '狀態': '體重正常', '身高': '169', '體重': '56'},
#  {'BMI': '21.3', '姓名': '林建勳', '狀態': '體重正常', '身高': '180', '體重': '69'},
#  {'BMI': '22.5', '姓名': '林向鈺', '狀態': '體重正常', '身高': '166', '體重': '62'},
#  {'BMI': '21.8', '姓名': '李淑芳', '狀態': '體重正常', '身高': '174', '體重': '66'},
#  {'BMI': '25.77', '姓名': '黃佩玲', '狀態': '體重過重', '身高': '166', '體重': '71'},
#  {'BMI': '16.36', '姓名': '林希啟', '狀態': '體重過輕', '身高': '180', '體重': '53'},
#  {'BMI': '16.85', '姓名': '林佳慧', '狀態': '體重過輕', '身高': '179', '體重': '54'},
#  {'BMI': '21.45', '姓名': '陳彥治', '狀態': '體重正常', '身高': '187', '體重': '75'},
#  {'BMI': '25.04', '姓名': '劉萬季', '狀態': '體重過重', '身高': '166', '體重': '69'},
#  {'BMI': '23.48', '姓名': '藍哲嘉', '狀態': '體重正常', '身高': '188', '體重': '83'},
#  {'BMI': '24.24', '姓名': '陳樂紫', '狀態': '體重過重', '身高': '156', '體重': '59'},
#  {'BMI': '24.16', '姓名': '龐皓芳', '狀態': '體重過重', '身高': '169', '體重': '69'},
#  {'BMI': '21.04', '姓名': '王惠皓', '狀態': '體重正常', '身高': '185', '體重': '72'},
#  {'BMI': '27.73', '姓名': '林清英', '狀態': '輕度肥胖', '身高': '173', '體重': '83'},
#  {'BMI': '22.94', '姓名': '元延辛', '狀態': '體重正常', '身高': '159', '體重': '58'},
#  {'BMI': '28.65', '姓名': '鄧亭聿', '狀態': '輕度肥胖', '身高': '165', '體重': '78'}]
